# %% [markdown]
# # Data Preprocessing

# %%
#install pyspark and spark-nlp
# !pip install pyspark
# !pip install spark-nlp
# !pip install nltk
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.10/dist-packages (3.5.2)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Requirement already satisfied: spark-nlp in /usr/local/lib/python3.10/dist-packages (5.4.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)

# %%
# Import modules
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pyspark.sql import SparkSession
import sparknlp
import json
from pyspark.ml import Pipeline
from pyspark.sql import SparkSession
import pyspark.sql.functions as F
from sparknlp.annotator import *
import nltk
from nltk.corpus import stopwords

# %%
spark = SparkSession.builder \
    .appName("SparkNLP_StopWords_Stemming") \
    .master("local[4]") \
    .config("spark.driver.memory", "4G") \
    .config("spark.serializer", "org.apache.spark.serializer.KryoSerializer") \
    .config("spark.kryoserializer.buffer.max", "2000M") \
    .getOrCreate()

# %%
# start the spark nlp session
spark = sparknlp.start()

# %%
# training data
headlines = json.load(open("training_data.json"))

#convert data to dataframe
df = spark.createDataFrame([(k, v) for k, v in headlines.items()], ["id", "text"])

df.toPandas()
# Out:
#       id                                               text
# 0      0  كرمان بك باقييف يتسلم مقاليد السلطة في منصب ال...
# 1      3    رويترز: مهرب يغرق 50 مهاجرا قبالة الساحل اليمني
# 2      4   ندى أمين: حلمت بأنني سأصل بطريقة ما إلى إسرائيل!
# 3      5                     ديبالا يقارن بين رونالدو وميسي
# 4      7  ترامب وآبي يناقشان الوضع في سوريا وسبل الضغط ع...
# ..   ...                                                ...
# 255  306  تفنيد روسي جديد لرواية الصاروخ والطائرة المالي...
# 256  307  موسكو: صواريخ ترامب الذكية يجب أن تستهدف الإره...
# 257  308   ظريف يؤكد لقاءاته مع كيري لمناقشة الاتفاق النووي
# 258  309                       مؤسسة روس كوسموس تغير شعارها
# 259  310  محمد بن سلمان يعلن حزمة إصلاحات ستدرج السعودية...
#
# [260 rows x 2 columns]

# %%
#get stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('arabic'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# define preprocessing pipeline
